# %% [markdown]
# <a href="https://colab.research.google.com/github/zihadbinjahangir/Loan/blob/main/Task3ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/saahiluppal/catr.git
# Out:
# Cloning into 'catr'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 121 (delta 48), reused 36 (delta 36), pack-reused 57
# Receiving objects: 100% (121/121), 3.05 MiB | 17.95 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
# %cd catr/
# Out:
# /content/catr

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 15.5 MB/s
# ...
#      |████████████████████████████████| 101 kB 13.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 53.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 62.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python main.py
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100% 171M/171M [00:00<00:00, 203MB/s]
# Number of params: 83959866
# Downloading: 100% 226k/226k [00:00<00:00, 687kB/s]
# Downloading: 100% 28.0/28.0 [00:00<00:00, 29.0kB/s]
# Downloading: 100% 570/570 [00:00<00:00, 496kB/s]
# Train: 7323
# Valid: 1830
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Start Training..
# Epoch: 0
# ...

# %%
# !python predict.py --path /content/drive/MyDrive/coco/train2017/1.png
# Out:
# Downloading: "https://github.com/saahiluppal/catr/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
# 100% 322M/322M [00:18<00:00, 18.0MB/s]
# /content/catr/models/position_encoding.py:38: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
# A woman in a kimono standing next to a woman.

# %%
# !python predict.py --path /content/drive/MyDrive/coco/train2017/3.png
# Out:
# Using cache found in /root/.cache/torch/hub/saahiluppal_catr_master
# /content/catr/models/position_encoding.py:38: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
# A man sitting on the ground with a laptop computer.

# %%
# !python predict.py --path .github/airplane.png
# Out:
# Using cache found in /root/.cache/torch/hub/saahiluppal_catr_master
# /content/catr/models/position_encoding.py:38: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
# A large plane is on a runway with a sky background

# %%
# !python main.py
# Out:
# Initializing Device: cuda
# Number of params: 83959866
# Train: 7323
# Valid: 1830
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loading Checkpoint...
# Start Training..
